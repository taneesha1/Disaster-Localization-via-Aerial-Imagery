# %%
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense,Conv2D,Flatten,Dropout,MaxPooling2D,LeakyReLU,BatchNormalization
from keras import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, initializers
from tensorflow.keras.optimizers import AdamW

# %%
early_stop = EarlyStopping(
    monitor='val_loss',      
    patience=5,              
    restore_best_weights=True
)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/aiderdata/AIDER",
    validation_split=0.15,
    subset="training",
    seed=123,
    image_size=(256, 256),
    batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/aiderdata/AIDER",
    validation_split=0.15,
    subset="validation",
    seed=123,
    image_size=(256, 256),
    batch_size=64
)
# Out:
# Found 6433 files belonging to 5 classes.
# Using 5469 files for training.
# Found 6433 files belonging to 5 classes.
# Using 964 files for validation.

# %%
from tensorflow.keras import layers
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),         
    layers.RandomRotation(0.25),             
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1)
])

# %%
normalization_layer = layers.Rescaling(1./255)
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x, y: (data_augmentation(normalization_layer(x)), y), num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %%
model= Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='same',input_shape=(256,256,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,kernel_size=(3,3),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Conv2D(32,kernel_size=(3,3),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Conv2D(32,kernel_size=(3,3),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Conv2D(32,kernel_size=(3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64))
model.add(LeakyReLU(alpha=0.1))

model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_40 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_54 (LeakyReLU)      │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_55 (LeakyReLU)      │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_40 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_56 (LeakyReLU)      │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_41 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_57 (LeakyReLU)      │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_42 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_58 (LeakyReLU)      │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_43 (MaxPooling2D) │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_14 (Flatten)            │ (None, 1568)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │       100,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_59 (LeakyReLU)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 138,629 (541.52 KB)
#  Trainable params: 138,629 (541.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(train_ds,epochs=30,validation_data=val_ds,callbacks=[early_stop])
# Out:
# Epoch 1/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 46s 461ms/step - accuracy: 0.6418 - loss: 1.1547 - val_accuracy: 0.6981 - val_loss: 0.8375
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 434ms/step - accuracy: 0.6886 - loss: 0.8431 - val_accuracy: 0.7116 - val_loss: 0.7765
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 444ms/step - accuracy: 0.7202 - loss: 0.7771 - val_accuracy: 0.7127 - val_loss: 0.7792
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 446ms/step - accuracy: 0.7389 - loss: 0.7119 - val_accuracy: 0.7251 - val_loss: 0.7127
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 435ms/step - accuracy: 0.7368 - loss: 0.6856 - val_accuracy: 0.7334 - val_loss: 0.7119
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 432ms/step - accuracy: 0.7570 - loss: 0.6368 - val_accuracy: 0.7407 - val_loss: 0.7741
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 435ms/step - accuracy: 0.7781 - loss: 0.5916 - val_accuracy: 0.7459 - val_loss: 0.6774
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 443ms/step - accuracy: 0.7848 - loss: 0.5625 - val_accuracy: 0.8185 - val_loss: 0.5276
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 452ms/step - accuracy: 0.8032 - loss: 0.5261 - val_accuracy: 0.8154 - val_loss: 0.5017
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 441ms/step - accuracy: 0.8133 - loss: 0.5064 - val_accuracy: 0.7759 - val_loss: 0.6119
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 440ms/step - accuracy: 0.8064 - loss: 0.5042 - val_accuracy: 0.7925 - val_loss: 0.5699
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 451ms/step - accuracy: 0.8268 - loss: 0.4568 - val_accuracy: 0.7905 - val_loss: 0.5347
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 443ms/step - accuracy: 0.8261 - loss: 0.4706 - val_accuracy: 0.8268 - val_loss: 0.4905
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 443ms/step - accuracy: 0.8228 - loss: 0.4797 - val_accuracy: 0.8527 - val_loss: 0.4395
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 440ms/step - accuracy: 0.8475 - loss: 0.4092 - val_accuracy: 0.8102 - val_loss: 0.5124
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 450ms/step - accuracy: 0.8355 - loss: 0.4224 - val_accuracy: 0.8371 - val_loss: 0.4790
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 443ms/step - accuracy: 0.8436 - loss: 0.4173 - val_accuracy: 0.8641 - val_loss: 0.4164
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 435ms/step - accuracy: 0.8587 - loss: 0.3857 - val_accuracy: 0.8371 - val_loss: 0.4538
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 431ms/step - accuracy: 0.8490 - loss: 0.4014 - val_accuracy: 0.8620 - val_loss: 0.4197
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 441ms/step - accuracy: 0.8571 - loss: 0.3903 - val_accuracy: 0.8496 - val_loss: 0.4189
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 429ms/step - accuracy: 0.8588 - loss: 0.3848 - val_accuracy: 0.8703 - val_loss: 0.3937
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 435ms/step - accuracy: 0.8620 - loss: 0.3759 - val_accuracy: 0.8454 - val_loss: 0.4382
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 431ms/step - accuracy: 0.8591 - loss: 0.3615 - val_accuracy: 0.8651 - val_loss: 0.4071
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 439ms/step - accuracy: 0.8716 - loss: 0.3626 - val_accuracy: 0.8506 - val_loss: 0.4117
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 427ms/step - accuracy: 0.8645 - loss: 0.3690 - val_accuracy: 0.8745 - val_loss: 0.3909
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 436ms/step - accuracy: 0.8781 - loss: 0.3454 - val_accuracy: 0.8683 - val_loss: 0.3932
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 438ms/step - accuracy: 0.8702 - loss: 0.3479 - val_accuracy: 0.8568 - val_loss: 0.4001
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 441ms/step - accuracy: 0.8635 - loss: 0.3552 - val_accuracy: 0.8662 - val_loss: 0.3759
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 432ms/step - accuracy: 0.8832 - loss: 0.3120 - val_accuracy: 0.8641 - val_loss: 0.3671
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 38s 431ms/step - accuracy: 0.8746 - loss: 0.3395 - val_accuracy: 0.8817 - val_loss: 0.3864
